# %% [markdown]
# # DRAS scenario generation

# %% [markdown]
# ### library importation, constant definition and data loading from files

# %% [markdown]
# The next cell defines the imports nedeed to execute the notebook

# %%
import pandas as pd
#!pip install geopandas
import geopandas as gpd
import matplotlib.pyplot as plt
# %pylab inline
from math import sin, cos, sqrt, atan2, radians
pd.set_option('precision', 2)
from functools import reduce
import os
from operator import truediv
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The next cell defines the contanst used by the procedures bellow

# %%
instance_dir = '../dras-controller/instances/'

ins_file = 'ins'
ref_file = 'ref'
w_file = 'w'

# %% [markdown]
# INS
# 1 5 // client-number server-number
# 5 0.5 0.5 1 1 // client-server-number PAND PAD CRND CND
# 800 20 1 // schedule-duration interval-number kw-dolar

# %% [markdown]
# # example3
#
# the secenarios are generated from swf files

# %%
example = 'example3'
numpy.random.seed(seed=111)

# %% [markdown]
# ## ins

# %%
C = 9
R = 28
schedule_duration  = 3600
K = 60
file_name = instance_dir + example + '/'+  ins_file
 
d = {'C': [C], 'R': [R]}
first = pd.DataFrame(data=d)
first_name = file_name + "_tmp1"
first.to_csv(first_name, sep=' ', encoding='utf-8', index=False, header=False)

d = {'RN': [int(R/C) for i in range(C)], 
     'PAND': [0.5 for i in range(C)],
     'PAD': [0.5 for i in range(C)],
     'CRND': [1 for i in range(C)], 
     'CRD': [1 for i in range(C)]}
second = pd.DataFrame(data=d)
 
second_name = file_name + "_tmp2"
second.to_csv(second_name, sep=' ', encoding='utf-8', index=False, header=False)

d = {'schedule_duration': [schedule_duration],
     'K': [K],
     'kwdolar': [0]
    }
third = pd.DataFrame(data=d)
third_name = file_name + "_tmp3"
third.to_csv(third_name, sep=' ', encoding='utf-8', index=False, header=False)

filenames = [first_name,second_name,third_name]
with open(file_name, 'w') as outfile:
    for fname in filenames:    
        with open(fname) as infile:
            for line in infile:
                outfile.write(line)
        os.remove(fname)

# %% [markdown]
# ## w

# %%
loss_offset = 0
trace_offset = 0
expansion_coefficient = 5

##### tomar 5 horas y hacer que el tiepo de arribo sea el resto entre 3600!!!!
numpy.random.seed(seed=111)

# read from worload exp1
exp1 = 'swf/exp1.swf'
data = pd.read_csv(exp1, header=None,sep='\t',skiprows=0,)
data.columns = [
    'x1', 'arriveTime','x3', 'x4','x5', 'x6','x7', 'x8', 
     'x9', 'x10','x11', 'x12','x13', 'x14','x15', 'x16',
                'x17','x18', 'mips','x20', 'x21','x22', 'type',]
data = data.query('arriveTime >= ' + str(trace_offset) + ' and arriveTime < '  + str(trace_offset) + ' + 3600')
data['arriveTime'] = data['arriveTime'] - trace_offset

W = data.shape[0]
server_mips = 1000

data['deadline_l'] = data.apply(lambda e: int(e.mips * 100 /server_mips),axis = 1) 
data['deadline_m'] = data.apply(lambda e: int(e.mips * 100/server_mips),axis = 1) 
data['deadline_h'] = data.apply(lambda e: int(e.mips * 100/server_mips),axis = 1) 


low_loss_1_floor = 1 + loss_offset
low_loss_1_ceil = 5 + loss_offset
low_loss_2_floor = 5 + loss_offset
low_loss_2_ceil = 10 + loss_offset
low_loss_3_floor = 10 + loss_offset
low_loss_3_ceil = 15 + loss_offset

data['loss_l'] = numpy.random.randint(low_loss_1_floor,low_loss_2_ceil + 1, size=W)
data['loss_m'] = numpy.random.randint(low_loss_2_floor,low_loss_2_ceil + 1,  size=W)
data['loss_h'] = numpy.random.randint(low_loss_3_floor,low_loss_3_ceil + 1, size=W)

clientId = 0
for deadline_index in ['deadline_l','deadline_m','deadline_h',]:
    for loss_index in ['loss_l','loss_m','loss_h',]:
        
        file_name = instance_dir + example + '/'+  w_file
        file_name_client = file_name + str(clientId)    
        d = {'W': [W]}
        first = pd.DataFrame(data=d)
        first_name = file_name_client + "_tmp1"
        first.to_csv(first_name, sep=' ', encoding='utf-8', index=False, header=False)
        d = {'clientId': [clientId for i in range(W)], 
             'mips': data['mips'],
             'arriveTime': data['arriveTime'],
             'deadline': data[deadline_index], 
             'deferable': [1 for i in range(W)],
             'loss':  data[loss_index],
             'type': data['type']    
            }
        second = pd.DataFrame(data=d) 
        second_name = file_name_client + "_tmp2"
        second.to_csv(second_name, sep=' ', encoding='utf-8', index=False, header=False)

        filenames = [first_name,second_name]
        with open(file_name_client, 'w') as outfile:
            for fname in filenames:    
                 with open(fname) as infile:
                    for line in infile:
                        outfile.write(line)
                    os.remove(fname)
        clientId = clientId+1

#filename = '../dras-controller/instances/example3/w1'
#data = pd.read_csv(filename, header=None,sep=' ',skiprows=1,)
#data


data
# Out:
#         x1  arriveTime  x3   x4  x5    x6     x7  x8   x9  x10  ...  x20  x21  \
# 562    563           5   6   39   1  0.03   7188   1  900   -1  ...  300  300
# 563    564          37   4   29   1  0.03   7213   1  900   -1  ...  300  300
# 564    565          74  12   40   1  0.04   7221   1  900   -1  ...  300  300
# 565    566         103  13   30   1  0.03   7184   1  900   -1  ...  300  300
# 566    567         134  12   36   1  0.04   7201   1  900   -1  ...  300  300
# 567    568         171   2   27   1  0.02   7193   1  900   -1  ...  300  300
# 568    569         226  10    7   1  0.02   7188   1  900   -1  ...  300  300
# 569    570         256  10  120   1  0.01   7193   1  900   -1  ...  300  300
# 570    571         279   2  112   1  0.05   7209   1  900   -1  ...  300  300
# 571    572         306   5  110   1  0.03   7201   1  900   -1  ...  300  300
# 572    573         316  10    1   1  0.09  12423   2  900   -1  ...  300  300
# 573    574         333   8   94   1  0.03   7188   1  900   -1  ...  300  300
# 574    575         354   2    5   1  0.01   9581   1  960   -1  ...  300  300
# 575    576         358  13   63   1  0.02   7209   1  900   -1  ...  300  300
# 576    577         386  15   43   1  0.03   7209   1  900   -1  ...  300  300
# 577    578         414   2   53   1  0.04   7201   1  900   -1  ...  300  300
# 578    579         442   4   99   1  0.03   7197   1  900   -1  ...  300  300
# 579    580         444   2  262   1  0.00   1196   8  960   -1  ...  300  300
# 580    581         454   2   31   1  0.04   3985   1  900   -1  ...  300  300
# 581    582         479  12   32   1  0.03   7209   1  900   -1  ...  300  300
# 582    583         508  13   29   1  0.03   7201   1  900   -1  ...  300  300
# 583    584         531   5   25   1  0.04   7201   1  900   -1  ...  300  300
# 584    585         557   9   25   1  0.04   7209   1  900   -1  ...  300  300
# 585    586         582  14   20   1  0.04   7201   1  900   -1  ...  300  300
# 586    587         609   2    5   1  0.02   7193   1  900   -1  ...  300  300
# 587    588         634   7   53   1  0.04   7209   1  900   -1  ...  300  300
# 588    589         660  11   38   1  0.02   7201   1  900   -1  ...  300  300
# 589    590         685  16   36   1  0.03   7213   1  900   -1  ...  300  300
# 590    591         712   4   42   1  0.01   7193   1  900   -1  ...  300  300
# 591    592         738   8   25   1  0.03   7193   1  900   -1  ...  300  300
# ...    ...         ...  ..  ...  ..   ...    ...  ..  ...  ...  ...  ...  ...
# 985    986        3332   9   22   1  0.01  12587   1  900   -1  ...  300  300
# 986    987        3338   3   22   1  0.06   7205   1  900   -1  ...  300  300
# 987    988        3345  11   16   1  0.01   7197   1  900   -1  ...  300  300
# 988    989        3369   4  162   1  0.04   3973   1  900   -1  ...  300  300
# 989    990        3379   7   22   1  0.04   7197   1  900   -1  ...  300  300
# 990    991        3397   4  144   1  0.05   7201   1  900   -1  ...  300  300
# 991    992        3430   5  271   1  0.04   3977   1  900   -1  ...  300  300
# 992    993        3439   7   53   1  0.00    599  16  960   -1  ...  300  300
# 993    994        3445  21   27   1  0.04  26530   1  900   -1  ...  300  300
# 994    995        3450  16   47   1  0.03  26579   1  900   -1  ...  300  300
# 995    996        3456   2   10   1  0.04   3973   1  900   -1  ...  300  300
# 996    997        3457   6  362   1  0.03   3969   1  900   -1  ...  300  300
# 997    998        3458   8   45   1  0.05  26587   1  900   -1  ...  300  300
# 998    999        3465  12   38   1  0.06  32354   1  900   -1  ...  300  300
# 999   1000        3469   2  172   1  0.01   3961   1  900   -1  ...  300  300
# 1000  1001        3474   3   38   1  0.06  26558   1  900   -1  ...  300  300
# 1001  1002        3490  16   98   1  0.00   1197   8  360   -1  ...  300  300
# 1002  1003        3492  14   12   1  0.02   7197   1  900   -1  ...  300  300
# 1003  1004        3509   4  162   1  0.02   3977   1  900   -1  ...  300  300
# 1004  1005        3528   8  163   1  0.02   7188   1  900   -1  ...  300  300
# 1005  1006        3533   3    7   1  0.04   7217   1  900   -1  ...  300  300
# 1006  1007        3543   2  195   1  0.02   3969   1  900   -1  ...  300  300
# 1007  1008        3551  15   21   1  0.03   7188   1  900   -1  ...  300  300
# 1008  1009        3557   9    7   1  0.01   9572   1  960   -1  ...  300  300
# 1009  1010        3558   9   21   1  0.02   7217   1  900   -1  ...  300  300
# 1010  1011        3564   2    1   1  0.03   7197   1  900   -1  ...  300  300
# 1011  1012        3571  10   23   1  0.04   7193   1  900   -1  ...  300  300
# 1012  1013        3576   5   32   1  0.06   7201   1  900   -1  ...  300  300
# 1013  1014        3582  14  150   1  0.01   9572   1  960   -1  ...  300  300
# 1014  1015        3587   9  148   1  0.05   7188   1  900   -1  ...  300  300
#
#        x22  type  deadline_l  deadline_m  deadline_h  loss_l  loss_m  loss_h
# 562   0.12     0         390         390         390      15      19      20
# 563   0.12     0         290         290         290      15      15      24
# 564   0.12     0         400         400         400      15      20      22
# 565   0.12     0         300         300         300      17      18      20
# 566   0.12     0         360         360         360      14      19      21
# 567   0.12     0         270         270         270      20      16      25
# 568   0.12     0          70          70          70      13      16      25
# 569   0.12     0        1200        1200        1200      17      17      22
# 570   0.12     0        1120        1120        1120      13      17      21
# 571   0.12     0        1100        1100        1100      19      19      22
# 572   0.12     1          10          10          10      18      19      22
# 573   0.12     0         940         940         940      20      15      25
# 574   0.12     1          50          50          50      18      19      24
# 575   0.12     0         630         630         630      12      19      25
# 576   0.12     0         430         430         430      11      19      22
# 577   0.12     0         530         530         530      19      16      21
# 578   0.12     0         990         990         990      13      19      25
# 579   0.12     0        2620        2620        2620      16      19      20
# 580   0.12     0         310         310         310      17      16      21
# 581   0.12     0         320         320         320      19      16      25
# 582   0.12     0         290         290         290      16      16      25
# 583   0.12     0         250         250         250      17      17      24
# 584   0.12     0         250         250         250      16      16      25
# 585   0.12     0         200         200         200      19      20      25
# 586   0.12     0          50          50          50      17      18      21
# 587   0.12     0         530         530         530      13      20      22
# 588   0.12     0         380         380         380      17      16      24
# 589   0.12     0         360         360         360      15      16      21
# 590   0.12     0         420         420         420      14      19      25
# 591   0.12     0         250         250         250      18      17      22
# ...    ...   ...         ...         ...         ...     ...     ...     ...
# 985   0.12     0         220         220         220      14      20      21
# 986   0.12     0         220         220         220      13      16      23
# 987   0.12     0         160         160         160      11      19      24
# 988   0.12     0        1620        1620        1620      11      17      21
# 989   0.12     0         220         220         220      16      19      22
# 990   0.12     0        1440        1440        1440      20      19      21
# 991   0.12     0        2710        2710        2710      20      20      24
# 992   0.12     0         530         530         530      18      20      24
# 993   0.12     0         270         270         270      11      20      25
# 994   0.12     0         470         470         470      19      20      22
# 995   0.12     0         100         100         100      12      19      21
# 996   0.12     0        3620        3620        3620      16      16      22
# 997   0.12     0         450         450         450      12      20      25
# 998   0.12     0         380         380         380      20      15      21
# 999   0.12     0        1720        1720        1720      14      17      21
# 1000  0.12     0         380         380         380      16      16      20
# 1001  0.12     0         980         980         980      19      18      21
# 1002  0.12     0         120         120         120      12      20      24
# 1003  0.12     0        1620        1620        1620      20      15      24
# 1004  0.12     0        1630        1630        1630      18      19      24
# 1005  0.12     0          70          70          70      20      19      21
# 1006  0.12     0        1950        1950        1950      13      15      22
# 1007  0.12     0         210         210         210      13      15      25
# 1008  0.12     0          70          70          70      16      15      21
# 1009  0.12     0         210         210         210      13      15      25
# 1010  0.12     0          10          10          10      14      17      25
# 1011  0.12     0         230         230         230      13      18      20
# 1012  0.12     0         320         320         320      19      16      21
# 1013  0.12     0        1500        1500        1500      16      18      24
# 1014  0.12     0        1480        1480        1480      16      17      22
#
# [453 rows x 29 columns]

# %%
filename = '/home/jmurana/code/cloudsim-cecal/workload/jobType/30 weeks/exp5.swf'
data = pd.read_csv(filename, header=None,sep='\t',skiprows=0,)
data.columns = [
    'x1', 'x2','x3', 'x4','x5', 'x6','x7', 'x8', 
     'x9', 'x10','x11', 'x12','x13', 'x14','x15', 'x16',
                'x17','x18', 'x19','x20', 'x21','x22', 'x23',]

data['x2'].plot()
