# %% [markdown]
# # Report 1

# %% [markdown]
# ### library importation, constant definition and data loading from files

# %% [markdown]
# The next cell defines the imports nedeed to execute the notebook

# %%
import pandas as pd
#!pip install geopandas
import geopandas as gpd
import matplotlib.pyplot as plt
# %pylab inline
from math import sin, cos, sqrt, atan2, radians
pd.set_option('precision', 5)
from functools import reduce
import os
from operator import truediv
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np

import os
import sys
module_path = os.path.abspath(os.path.join('.'))
if module_path not in sys.path:
    sys.path.append(module_path)
import pareto

pd.set_option('display.float_format', lambda x: '%.2f' % x)

from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>div.output_scroll { height: 44em; }</style>

# %% [markdown]
# The next cell defines the contanst used by the procedures bellow

# %%
report1_dir = '../dras-controller/output/'
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    display(x)
    #print(x.to_latex(index=False)) 
    pd.reset_option('display.max_rows')
    
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

def highlight_min(s):
    is_min = s == s.min()
    return ['background-color: yellow' if v else '' for v in is_min]

# %%
def get_dist(x_1,x_2,y_1,y_2):
  d = math.sqrt((x_1-x_2)*(x_1-x_2) + (y_1-y_2)*(y_1-y_2))
  return d

def get_dist_norm(x_1,x_2,y_1,y_2):
  d = math.sqrt((x_1-x_2)*(x_1-x_2) + (y_1-y_2)*(y_1-y_2))
  return d/((y_1-y_2) + (x_2-x_1))


def changeLow(name):
    if "highest-deadline-first" in name:
        return "HDF"
    if "highest-penalty-first" in name:
        return "HPF"
    if "highest-mips-first" in name:
        return "HMF"
    if "lowest-id-first" in name:
        return "LIF"


def getTipo(name):
    if "medium" in name:
        return "hom-hom"
    if "small" in name:
        return "hom-hom"
    if "large" in name:
        return "hom-hom"
    
    if "5-0-0" in name and "het" in name:
        return "hom-het"
    if "0-10-0" in name and "het" in name:
        return "hom-het"
    if "0-0-30" in name and "het" in name:
        return "hom-het"
    
    if "-20-" in name and "hom" in name:
        return "het-hom"
    if "-3-" in name and "hom" in name:
        return "het-hom"
    if "-6-" in name and "hom" in name:
        return "het-hom"
    
    if "-20-" in name and "het" in name:
        return "het-het"
    if "-3-" in name and "het" in name:
        return "het-het"
    if "-6-" in name and "het" in name:
        return "het-het"
    
    return name

def getSize(name):
    if "medium" in name:
        return "medium"
    if "small" in name:
        return "small"
    if "large" in name:
        return "large"
    
    if "5-0-0" in name and "het" in name:
        return "small"
    if "0-10-0" in name and "het" in name:
        return "medium"
    if "0-0-30" in name and "het" in name:
        return "large"
    
    if "-20-" in name and "hom" in name:
        return "large"
    if "-3-" in name and "hom" in name:
        return "small"
    if "-6-" in name and "hom" in name:
        return "medium"
    
    if "-20-" in name and "het" in name:
        return "large"
    if "-3-" in name and "het" in name:
        return "small"
    if "-6-" in name and "het" in name:
        return "medium"
    
    return name

def getHeuLow(name):
    return name.split("_")[1]

def getHeu(name):
    if "BTO-g" in name:
        return "BTO-g"
    if "BTO-d" in name:
        return "BTO-d"
    if "ideal" in name:
        return "ideal"
    if "nash" in name:
        return "nash"
    if "PMP" in name:
        return "PMP"
    if "bau" in name:
        return "bau"
    return name

def getInstance(name):
    if "medium-tol1" in name:
        return name[-15:-4]
    if "medium" in name:
        return name[-17:-4]
    if "small-tol1" in name:
        return name[-14:-4]
    if "small" in name:
        return name[-16:-4]
    if "large-tol1" in name:
        return name[-14:-4]
    if "large" in name:
        return name[-16:-4]
    if "DRD" in name:
        return "DRD" + name.split("DRD")[1][:-4]



def fotmatTable(table):
    newTable = pd.DataFrame()
    newTable['heu_high'] = table['heu']
    newTable['heu_low'] = table.apply(lambda e:changeLow(e['low']),axis = 1)
    
    table['low']    
    #newTable['type'] = table['tipo']
    newTable['reduction'] = table['AVG clients reduction (W)'
                                 ].round(2).astype(str).str.cat(table['STD reduction (W)'
                                                            ].round(2).astype(str)  
                                                                       , sep =" $\pm$ ") 
    newTable['cost'] = table['AVG dcCost'
                                 ].round(2).astype(str).str.cat(table['STD dcCost'
                                                            ].round(2).astype(str)  
                                                                       , sep =" $\pm$ ")
    newTable['#V'] = table['AVG #V'
                                 ].round(2).astype(str).str.cat(table['STD #V'
                                                            ].round(2).astype(str)  
                                                                       , sep =" $\pm$ ")
    newTable['VT'] = table['AVG VT'
                                 ].round(2).astype(str).str.cat(table['STD VT'
                                                            ].round(2).astype(str)  
                                                                       , sep =" $\pm$ ")

    newTable['RDI'] = table['AVG RDI'
                                 ].round(2).astype(str).str.cat(table['STD RDI'
                                                            ].round(2).astype(str)  
                                                                       , sep =" $\pm$ ")
    newTable['dI'] = table['AVG dI'
                                 ].round(2).astype(str).str.cat(table['STD dI'
                                                            ].round(2).astype(str)  
                                                                       , sep =" $\pm$ ")
    newTable['#B'] = table['AVG #B'
                                 ].round(2).astype(str).str.cat(table['STD #B'
                                                            ].round(2).astype(str)  
                                                                       , sep =" $\pm$ ")
    
    newTable.style.apply(highlight_max, subset=['reduction','cost']).apply(highlight_min, subset=['VT'])
    
    return newTable

# %% [markdown]
# # plot client function
#
# the scenarios are generated from swf files

# %%
def printHeu(name):
    
    data = pd.DataFrame()
    for filename in [f for f in os.listdir(report1_dir +'/') if ".FUN" in f 
                     and not 'pareto' in f
                     and not 'ideal' in f
                    
                    ]:

        aux =  report1_dir + filename  
        dataAux = pd.read_csv(aux, header=None,sep=' ',skiprows=0,)
        
        dataAux['instance'] = getHeu(filename)
        dataAux['heu'] = getInstance(filename)
        dataAux['low'] = getHeuLow(filename)
        dataAux['tipo'] = getTipo(filename)
        dataAux['size'] = getSize(filename)



        #print(data)
        dataAux = dataAux.fillna(0)
        dataAux = dataAux.replace(NaN,'0.0')
        dataAux = dataAux.replace('y','0.0')
        dataAux = dataAux.replace('err','0.0')
        dataAux.columns = [
                'i','offer ($)', 'clients reduction (W)','motor','err','dcCost','socialCost','#V','VT',
                           'heu','instance','low','tipo','size']
        data = data.append(dataAux)
    
    data = data.reset_index().drop(columns=['index'])
    
    
    data = data[['clients reduction (W)','dcCost','#V','VT',
                           'heu','instance','low','tipo','size']]
    data = data.round(2)
    
    dataMean = data.copy()
    
    
    dataMean = dataMean.groupby(['heu','tipo','low','size']).mean()
    #dataMean = dataMean.groupby(['heu','tipo']).mean()

    dataMean = dataMean.reset_index()
    dataMean.columns = ['heu','tipo','low','size','AVG clients reduction (W)','AVG dcCost','AVG #V','AVG VT']
    #dataMean.columns = ['AVG heu','tipo','AVG clients reduction (W)','AVG dcCost','AVG VT','AVG VT']

    dataStd = data.copy()

    
    dataStd = dataStd.groupby(['heu','tipo','low','size']).std()
    #dataStd = dataStd.groupby(['heu','tipo']).std()

    dataStd = dataStd.reset_index()
    dataStd = dataStd[['clients reduction (W)','dcCost','#V','VT']]
    dataStd.columns = ['STD reduction (W)','STD dcCost','STD #V','STD VT']
    
    dataCount = data.copy()
    dataCount['count'] = 1
    dataCount = dataCount.groupby(['heu','tipo','low','size']).sum()
    #dataCount = dataCount.groupby(['heu','tipo']).sum()

    dataCount = dataCount.reset_index()
    dataCount = dataCount[['count']]

    
    data = pd.concat([dataMean, dataStd], axis=1)
    data = pd.concat([data, dataCount], axis=1)

    
    data = data.sort_values(['heu','tipo']) 
    #data = data.sort_values(['tipo'])  

    
    lows = ['highest-penalty-first', 'highest-mips-first','highest-deadline-first']
    data = data[data['low'].isin(lows)]

    #print_full(fotmatTable(data[data['size']==name]))
    print_full(data[data['size']==name])
           

        
print('small')
printHeu('small')

print('medium')
printHeu('medium')

print('large')
printHeu('large')
# Out:
# small
#        heu     tipo                     low   size  AVG clients reduction (W)  \
# 2    BTO-d  het-het  highest-deadline-first  small                    1115.33
# 5    BTO-d  het-het      highest-mips-first  small                    1134.00
# 8    BTO-d  het-het   highest-penalty-first  small                    5932.67
# 17   BTO-d  het-hom  highest-deadline-first  small                    1100.67
# 20   BTO-d  het-hom      highest-mips-first  small                    1103.00
# 23   BTO-d  het-hom   highest-penalty-first  small                    6123.33
# 32   BTO-d  hom-het  highest-deadline-first  small                     700.00
# 35   BTO-d  hom-het      highest-mips-first  small                     715.33
# 38   BTO-d  hom-het   highest-penalty-first  small                    1724.00
# 47   BTO-d  hom-hom  highest-deadline-first  small                     707.00
# 50   BTO-d  hom-hom      highest-mips-first  small                     727.33
# 53   BTO-d  hom-hom   highest-penalty-first  small                    1747.67
# 65   BTO-g  het-het  highest-deadline-first  small                    1115.33
# 68   BTO-g  het-het      highest-mips-first  small                    1125.33
# 71   BTO-g  het-het   highest-penalty-first  small                    4761.67
# 80   BTO-g  het-hom  highest-deadline-first  small                    1098.67
# 83   BTO-g  het-hom      highest-mips-first  small                    1093.33
# 86   BTO-g  het-hom   highest-penalty-first  small                    5831.00
# 95   BTO-g  hom-het  highest-deadline-first  small                     696.00
# 98   BTO-g  hom-het      highest-mips-first  small                     707.67
# 101  BTO-g  hom-het   highest-penalty-first  small                    1774.33
# 110  BTO-g  hom-hom  highest-deadline-first  small                     705.00
# 113  BTO-g  hom-hom      highest-mips-first  small                     721.33
# 116  BTO-g  hom-hom   highest-penalty-first  small                    1680.00
# 128    PMP  het-het  highest-deadline-first  small                    1125.67
# 131    PMP  het-het      highest-mips-first  small                    1138.67
# 134    PMP  het-het   highest-penalty-first  small                    5961.33
# 143    PMP  het-hom  highest-deadline-first  small                    1108.00
# 146    PMP  het-hom      highest-mips-first  small                    1112.67
# 149    PMP  het-hom   highest-penalty-first  small                    5621.33
# 158    PMP  hom-het  highest-deadline-first  small                     705.67
# 161    PMP  hom-het      highest-mips-first  small                     719.00
# 164    PMP  hom-het   highest-penalty-first  small                    1881.00
# 173    PMP  hom-hom  highest-deadline-first  small                     721.33
# 176    PMP  hom-hom      highest-mips-first  small                     730.67
# 257    3179.33      3
# 260  975795.28      3
# 269     269.50      3
# 272     801.16      3
# 275   82214.86      3
# 284     964.75      3
# 287     781.73      3
# 290  166875.34      3
# medium
#        heu     tipo                     low    size  \
# 1    BTO-d  het-het  highest-deadline-first  medium
# 4    BTO-d  het-het      highest-mips-first  medium
# 7    BTO-d  het-het   highest-penalty-first  medium
# 16   BTO-d  het-hom  highest-deadline-first  medium
# 19   BTO-d  het-hom      highest-mips-first  medium
# 22   BTO-d  het-hom   highest-penalty-first  medium
# 31   BTO-d  hom-het  highest-deadline-first  medium
# 34   BTO-d  hom-het      highest-mips-first  medium
# 37   BTO-d  hom-het   highest-penalty-first  medium
# 46   BTO-d  hom-hom  highest-deadline-first  medium
# 49   BTO-d  hom-hom      highest-mips-first  medium
# 52   BTO-d  hom-hom   highest-penalty-first  medium
# 64   BTO-g  het-het  highest-deadline-first  medium
# 67   BTO-g  het-het      highest-mips-first  medium
# 70   BTO-g  het-het   highest-penalty-first  medium
# 79   BTO-g  het-hom  highest-deadline-first  medium
# 82   BTO-g  het-hom      highest-mips-first  medium
# 85   BTO-g  het-hom   highest-penalty-first  medium
# 94   BTO-g  hom-het  highest-deadline-first  medium
# 97   BTO-g  hom-het      highest-mips-first  medium
# 100  BTO-g  hom-het   highest-penalty-first  medium
# 109  BTO-g  hom-hom  highest-deadline-first  medium
# 112  BTO-g  hom-hom      highest-mips-first  medium
# 115  BTO-g  hom-hom   highest-penalty-first  medium
# 127    PMP  het-het  highest-deadline-first  medium
# 130    PMP  het-het      highest-mips-first  medium
# 133    PMP  het-het   highest-penalty-first  medium
# 142    PMP  het-hom  highest-deadline-first  medium
# 145    PMP  het-hom      highest-mips-first  medium
# 148    PMP  het-hom   highest-penalty-first  medium
# 157    PMP  hom-het  highest-deadline-first  medium
# 160    PMP  hom-het      highest-mips-first  medium
# 163    PMP  hom-het   highest-penalty-first  medium
# 172    PMP  hom-hom  highest-deadline-first  medium
# 175    PMP  hom-hom      highest-mips-first  medium
# 178    PMP  hom-hom   highest-penalty-first  medium
# 190    bau  het-het  highest-deadline-first  medium
# 193    bau  het-het      highest-mips-first  medium
# 196    bau  het-het   highest-penalty-first  medium
# 202    bau  het-hom  highest-deadline-first  medium
# 205    bau  het-hom      highest-mips-first  medium
# 208    bau  het-hom   highest-penalty-first  medium
# 214    bau  hom-het  highest-deadline-first  medium
# 217    bau  hom-het      highest-mips-first  medium
# 220    bau  hom-het   highest-penalty-first  medium
# 226    bau  hom-hom  highest-deadline-first  medium
# 229    bau  hom-hom      highest-mips-first  medium
# 232    bau  hom-hom   highest-penalty-first  medium
# 238   nash  het-het  highest-deadline-first  medium
# 241   nash  het-het      highest-mips-first  medium
# 244   nash  het-het   highest-penalty-first  medium
# 253   nash  het-hom  highest-deadline-first  medium
# 256   nash  het-hom      highest-mips-first  medium
# 259   nash  het-hom   highest-penalty-first  medium
# 268   nash  hom-het  highest-deadline-first  medium
# 271   nash  hom-het      highest-mips-first  medium
# 274   nash  hom-het   highest-penalty-first  medium
# 283   nash  hom-hom  highest-deadline-first  medium
# 15   BTO-d  het-hom  highest-deadline-first  large                    6397.67
# 18   BTO-d  het-hom      highest-mips-first  large                    6468.00
# 21   BTO-d  het-hom   highest-penalty-first  large                   35400.00
# 30   BTO-d  hom-het  highest-deadline-first  large                    8658.33
# 33   BTO-d  hom-het      highest-mips-first  large                    8725.00
# 36   BTO-d  hom-het   highest-penalty-first  large                   53866.00
# 45   BTO-d  hom-hom  highest-deadline-first  large                    8065.33
# 48   BTO-d  hom-hom      highest-mips-first  large                    8214.33
# 51   BTO-d  hom-hom   highest-penalty-first  large                   56674.33
# 63   BTO-g  het-het  highest-deadline-first  large                    6400.67
# 66   BTO-g  het-het      highest-mips-first  large                    6505.33
# 69   BTO-g  het-het   highest-penalty-first  large                   27418.00
# 78   BTO-g  het-hom  highest-deadline-first  large                    6299.67
# 81   BTO-g  het-hom      highest-mips-first  large                    6401.33
# 84   BTO-g  het-hom   highest-penalty-first  large                   33033.00
# 93   BTO-g  hom-het  highest-deadline-first  large                    8478.67
# 96   BTO-g  hom-het      highest-mips-first  large                    8604.67
# 99   BTO-g  hom-het   highest-penalty-first  large                   45862.00
# 108  BTO-g  hom-hom  highest-deadline-first  large                    7963.00
# 111  BTO-g  hom-hom      highest-mips-first  large                    8127.00
# 114  BTO-g  hom-hom   highest-penalty-first  large                   54391.67
# 126    PMP  het-het  highest-deadline-first  large                    6588.00
# 129    PMP  het-het      highest-mips-first  large                    6669.33
# 132    PMP  het-het   highest-penalty-first  large                   39325.67
# 141    PMP  het-hom  highest-deadline-first  large                    6659.00
# 144    PMP  het-hom      highest-mips-first  large                    6720.67
# 147    PMP  het-hom   highest-penalty-first  large                   39534.33
# 156    PMP  hom-het  highest-deadline-first  large                    8856.33
# 159    PMP  hom-het      highest-mips-first  large                    8888.00
# 162    PMP  hom-het   highest-penalty-first  large                   61499.67
# 171    PMP  hom-hom  highest-deadline-first  large                    8354.33
# 174    PMP  hom-hom      highest-mips-first  large                    8544.00
# 177    PMP  hom-hom   highest-penalty-first  large                   61422.33
# 189    bau  het-het  highest-deadline-first  large                       0.00
# 192    bau  het-het      highest-mips-first  large                       0.00
# 195    bau  het-het   highest-penalty-first  large                       0.00
# 201    bau  het-hom  highest-deadline-first  large                       0.00
# 204    bau  het-hom      highest-mips-first  large                       0.00
# 207    bau  het-hom   highest-penalty-first  large                       0.00
# 213    bau  hom-het  highest-deadline-first  large                       0.00
# 216    bau  hom-het      highest-mips-first  large                       0.00
# 219    bau  hom-het   highest-penalty-first  large                       0.00
# 225    bau  hom-hom  highest-deadline-first  large                       0.00
# 228    bau  hom-hom      highest-mips-first  large                       0.00
# 231    bau  hom-hom   highest-penalty-first  large                       0.00
# 237   nash  het-het  highest-deadline-first  large                    6551.67
# 240   nash  het-het      highest-mips-first  large                    6656.33
# 243   nash  het-het   highest-penalty-first  large                   17997.67
# 252   nash  het-hom  highest-deadline-first  large                    6517.33
# 255   nash  het-hom      highest-mips-first  large                    6625.67
# 258   nash  het-hom   highest-penalty-first  large                   14853.67
# 267   nash  hom-het  highest-deadline-first  large                    8808.67
# 213        0.00  11176.67        0.00               0.00        0.00     9.29
# 216        0.00  11176.67        0.00               0.00        0.00     9.29
# 219        0.00  11176.67        0.00               0.00        0.00     9.29
# 225        0.00  11263.00        0.00               0.00        0.00     0.00
# 228        0.00  11263.00        0.00               0.00        0.00     0.00
# 231        0.00  11263.00        0.00               0.00        0.00     0.00
# 237    43531.33   6934.00     8277.67            1376.38    11829.65  2373.03
# 240    43527.52   6939.00    16544.00            1366.79    11830.75  2382.20
# 243    42660.45  35902.67  3965881.33            5913.15    11500.53 15158.89
# 252    43532.08   6910.33    16672.33            1023.34    11843.35  2426.31
# 255    43527.24   6929.00    24143.67            1029.18    11843.78  2432.30
# 258    36378.06  26536.00   631986.33            9790.79    11456.17 26334.94
# 267    59822.75  11265.33    13878.33             557.20       21.02    32.01
# 270    59819.77  11254.33    11848.67             490.99       19.62    24.01
# 273    51622.98  53301.33  5706555.33            4393.51    12596.03 12160.57
# 282    59844.91  11366.67    15692.67             104.84        3.66    57.01
# 285    59838.69  11363.33    19166.67             112.70        4.31    55.32
# 288    51547.34  34452.67   227264.67            9907.69    14012.26 27693.16
#
#         STD VT  count
# 0       717.72      3
# 3      2174.76      3
# 6   3966543.15      3
# 15     2926.95      3
# 18     6695.20      3
# 21  6541155.47      3
# 30     2013.29      3
# 33     1753.34      3
# 36  2668435.42      3
# 45     2792.20      3
# 48     3317.86      3
# 51  4240710.55      3
# 63      339.66      3
# 66      131.77      3
# 69  3728164.33      3
# 78      562.40      3
# 81     1247.66      3
# 84  5984982.39      3
# 93       80.83      3
# 96      225.17      3
# 99  3358199.13      3
# 108     643.17      3
# 111       0.00      3
# 114 3555825.83      3
# 126   22819.01      3
# 129   15743.98      3
# 132 4782425.17      3
# 141   60633.71      3
# 144   32735.37      3
# 147 5877180.59      3
# 156   20312.34      3
# 159   15356.00      3
# 162  735869.84      3
# 171   51568.53      3
# 174   82090.72      3
# 177 2255110.66      3
# 189       0.00      3
# 192       0.00      3
# 195       0.00      3
# 201       0.00      3
# 204       0.00      3
# 207       0.00      3
# 213       0.00      3
# 216       0.00      3
# 219       0.00      3
# 225       0.00      3
# 228       0.00      3
# 231       0.00      3
# 237    4051.23      3
# 240    6152.67      3
# 243 2143912.74      3
# 252   10037.11      3
# 255   12739.15      3
# 258  663471.68      3
# 267    3236.86      3
# 270    4272.73      3
# 273 1445374.24      3
# 282    7205.96      3
# 285    9071.49      3
# 288  393633.95      3

# %%
def getIdealReduction(low,size,instance,data):
    return data[(data['instance']==instance) & (data['low']==low)
& (data['size']==size) & (data['heu']=='ideal')]['reduction']
    
def getIdealReductionGlobal(low,size,instance,data):
    aux = data[(data['instance']==instance)& (data['heu']=='ideal')& 
               (data['size']==size)]['reduction']
    aux = aux.sort_values(ascending=False)
    return aux.values[0]

def getNumberOfBestSolution(heu,low,dI,instance,data):
    aux = data.copy()
    aux = aux.groupby(['instance']).min()
    aux = aux.reset_index()
    
    aux = aux.apply(lambda x: 1 if dI == x.dI else 0,axis = 1)
    #aux = aux.apply(lambda x: 1 if dI == x.dI and not (x.heu==heu and x.low == low)  else 0,axis = 1)

    return aux.sum(axis = 0, skipna = True)

def getStrenght(reduction,cost,instance,data):
    aux = data.copy()
    ##aux = aux.groupby(['instance']).max()
    ##aux = aux.reset_index()
    
    aux3 = aux.apply(lambda x: 
                                  1 
                                  if instance >= x.instance
                                  and reduction >= x.reduction
                                  and cost <= x.cost 
                                  else 0,axis = 1)
    # less myself
    return (aux.sum(axis = 0, skipna = True) - 1 )

def printHeu(name):
    
    data = pd.DataFrame()
    for filename in [f for f in os.listdir(report1_dir +'/') if ".FUN" in f 
                     and not 'pareto' in f]:

        aux =  report1_dir + filename  
        dataAux = pd.read_csv(aux, header=None,sep=' ',skiprows=0,)
        
        dataAux['heu'] = getHeu(filename)
        dataAux['instance'] = getInstance(filename)
        dataAux['low'] = getHeuLow(filename)
        dataAux['tipo'] = getTipo(filename)
        dataAux['size'] = getSize(filename)



        #print(data)
        dataAux = dataAux.fillna(0)
        dataAux = dataAux.replace(NaN,'0.0')
        dataAux = dataAux.replace('y','0.0')
        dataAux = dataAux.replace('err','0.0')
        dataAux.columns = ['i','offer ($)', 'reduction','motor','err','cost','socialCost','#V','VT',
                           'heu','instance','low','tipo','size']
        data = data.append(dataAux)
    
    data = data.reset_index().drop(columns=['index'])
    
    
    data = data[['reduction','cost','#V','VT',
                           'heu','instance','low','tipo','size']]
    
    data = data.round(2)
    
    data = data[data['size']==name]
    data = data.reset_index().drop(columns=['index'])
    
    data['reduction_ideal'] = data.apply(lambda e:
                                         getIdealReduction(e['low'],e['size'],e['instance'],data).values[0]
                                         ,axis = 1)
    data['reduction_ideal_g'] = data.apply(lambda e:
                                         getIdealReductionGlobal(e['low'],e['size'],e['instance'],data)
                                         ,axis = 1)                                                 
              
    # delete ideal for normalizing
    data = data[data['heu']!='ideal']
    data = data.reset_index().drop(columns=['index'])
    
        
    data['RDI'] = data.apply(lambda e: get_dist_norm(0.0,e['cost'],
                                                    e.reduction_ideal,e['reduction']),axis = 1)
    
    data['dI'] = data.apply(lambda e: get_dist(0.0,e['cost'],
                                                     e.reduction_ideal_g,e['reduction']),axis = 1)
    
    
    
    # FILTER
    # only this heu
    lows = ['highest-penalty-first', 'highest-mips-first','highest-deadline-first','lowest-id-first']
    data = data[data['low'].isin(lows)]
    data = data.reset_index().drop(columns=['index'])
    
    # only one bau
    #bau = ['bau']
    #lows = ['highest-penalty-first', 'highest-mips-first','highest-deadline-first']
    #data = data[  ~((data['heu'].isin(bau)) & (data['low'].isin(lows)))]
    #data = data.reset_index().drop(columns=['index'])
    
    # drop unnecesay columns
    data = data.drop(columns=['reduction_ideal'])
    data = data.drop(columns=['reduction_ideal_g'])

    
    data['#B'] = data.apply(lambda e: getNumberOfBestSolution(e.heu,e.low,e.dI,e.instance,data),axis = 1)
    data['#B'] = data.apply(lambda e: getNumberOfBestSolution(e.heu,e.low,e.dI,e.instance,data),axis = 1)

    
    getStrenght(reduction,cost,instance,data)
    
    print_full(data.query("instance == 'DRD-3-1-1-het-1'"))
    
    
    dataMean = data.copy()
    dataMean = dataMean.groupby(['heu','low','size']).mean()
    #dataMean = dataMean.groupby(['heu','tipo']).mean()

    dataMean = dataMean.reset_index()
    dataMean.columns = ['heu','low','size','AVG clients reduction (W)',
                        'AVG dcCost','AVG #V','AVG VT','AVG RDI','AVG dI','AVG #B']

    dataStd = data.copy()

    
    dataStd = dataStd.groupby(['heu','low','size']).std()
    #dataStd = dataStd.groupby(['heu','tipo']).std()

    dataStd = dataStd.reset_index()
    dataStd = dataStd[['reduction','cost','#V','VT','RDI','dI','#B']]
    dataStd.columns = ['STD reduction (W)','STD dcCost','STD #V','STD VT','STD RDI','STD dI','STD #B']
    
    dataCount = data.copy()
    dataCount['count'] = 1
    dataCount = dataCount.groupby(['heu','low','size']).sum()
    #dataCount = dataCount.groupby(['heu','tipo']).sum()

    dataCount = dataCount.reset_index()
    dataCount = dataCount[['count']]

    
    data = pd.concat([dataMean, dataStd], axis=1)
    data = pd.concat([data, dataCount], axis=1)

    
    data = data.sort_values(['heu','low']) 
    #data = data.sort_values(['tipo'])  

    


    print_full(fotmatTable(data[data['size']==name]))
               

        

printHeu('small')

#print('medium')
#printHeu('medium')

#print('large')
#printHeu('large')
# Out:
#      reduction    cost       #V         VT    heu         instance  \
# 17      926.00 5882.40   819.00       0.00   nash  DRD-3-1-1-het-1
# 41      982.00  198.50   818.00     365.00    PMP  DRD-3-1-1-het-1
# 48      926.00  413.45   819.00       0.00    PMP  DRD-3-1-1-het-1
# 59      963.00   48.15   814.00       0.00  BTO-g  DRD-3-1-1-het-1
# 64     4324.00 8207.30 10010.00 1246396.00    PMP  DRD-3-1-1-het-1
# 75      900.00   45.00   814.00       0.00  BTO-g  DRD-3-1-1-het-1
# 81      975.00  382.75   824.00    1027.00    PMP  DRD-3-1-1-het-1
# 91     2892.00 4878.94  6081.00  846305.00   nash  DRD-3-1-1-het-1
# 111       0.00    0.00   814.00       0.00    bau  DRD-3-1-1-het-1
# 127     982.00 5868.23   818.00     365.00   nash  DRD-3-1-1-het-1
# 144       0.00    0.00   814.00       0.00    bau  DRD-3-1-1-het-1
# 145     950.00  109.30   817.00      77.00  BTO-d  DRD-3-1-1-het-1
# 169     950.00  237.50   817.00      77.00  BTO-g  DRD-3-1-1-het-1
# 171       0.00    0.00   814.00       0.00    bau  DRD-3-1-1-het-1
# 198     982.00  198.50   818.00     365.00  BTO-d  DRD-3-1-1-het-1
# 207     905.00   66.25   815.00       0.00  BTO-d  DRD-3-1-1-het-1
# 218       0.00    0.00   814.00       0.00    bau  DRD-3-1-1-het-1
# 229    3720.00 8742.00  8178.00  847637.00  BTO-g  DRD-3-1-1-het-1
# 236    4238.00 7784.65  9737.00 1039609.00  BTO-d  DRD-3-1-1-het-1
# 237     990.00 5867.06   829.00    2505.00   nash  DRD-3-1-1-het-1
#
#                         low     tipo   size  RDI      dI  #B
# 17          lowest-id-first  het-het  small 0.99 7054.49   0
# 41       highest-mips-first  het-het  small 0.88 3843.13   1
# 48          lowest-id-first  het-het  small 0.87 3915.89   0
# 59       highest-mips-first  het-het  small 0.71 3857.30   0
# 64    highest-penalty-first  het-het  small 0.94 8222.27   0
# 75          lowest-id-first  het-het  small 0.75 3920.26   0
# 81   highest-deadline-first  het-het  small 0.96 3864.00   0
# 91    highest-penalty-first  het-het  small 0.77 5246.07   0
# 111         lowest-id-first  het-het  small 1.00 4820.00   0
# 127      highest-mips-first  het-het  small 0.99 7011.87   0
# 144  highest-deadline-first  het-het  small 1.00 4820.00   0
# 145  highest-deadline-first  het-het  small 0.78 3871.54   0
# 169  highest-deadline-first  het-het  small 0.87 3877.28   0
# 171   highest-penalty-first  het-het  small 1.00 4820.00   0
# 198      highest-mips-first  het-het  small 0.88 3843.13   1
# 207         lowest-id-first  het-het  small 0.72 3915.56   0
# 218      highest-mips-first  het-het  small 1.00 4820.00   0
# 229   highest-penalty-first  het-het  small 0.90 8810.93   0
# 236   highest-penalty-first  het-het  small 0.93 7806.38   0
# 237  highest-deadline-first  het-het  small 1.00 7006.52   0
#    heu_high heu_low              reduction                   cost  \
# 0     BTO-d     HDF    905.75 $\pm$ 233.65      67.32 $\pm$ 29.01
# 1     BTO-d     HMF    919.92 $\pm$ 228.04      95.59 $\pm$ 49.76
# 2     BTO-d     HPF  3881.92 $\pm$ 2489.11   7560.7 $\pm$ 5325.31
# 3     BTO-d     LIF    916.92 $\pm$ 251.52    233.21 $\pm$ 190.37
# 4     BTO-g     HDF    903.75 $\pm$ 235.05      86.66 $\pm$ 73.95
# 5     BTO-g     HMF    911.92 $\pm$ 226.83      84.39 $\pm$ 38.72
# 6     BTO-g     HPF  3511.75 $\pm$ 2170.54   7331.5 $\pm$ 4927.76
# 7     BTO-g     LIF    896.17 $\pm$ 253.89    350.04 $\pm$ 307.92
# 8       PMP     HDF    915.17 $\pm$ 232.79    198.44 $\pm$ 195.89
# 9       PMP     HMF    925.25 $\pm$ 231.51     157.62 $\pm$ 97.52
# 10      PMP     HPF  3817.17 $\pm$ 2537.71   7492.4 $\pm$ 5131.79
# 11      PMP     LIF    925.25 $\pm$ 253.18    330.77 $\pm$ 200.66
# 12      bau     HDF          0.0 $\pm$ 0.0          0.0 $\pm$ 0.0
# 13      bau     HMF          0.0 $\pm$ 0.0          0.0 $\pm$ 0.0
# 14      bau     HPF          0.0 $\pm$ 0.0          0.0 $\pm$ 0.0
# 15      bau     LIF          0.0 $\pm$ 0.0          0.0 $\pm$ 0.0
# 16     nash     HDF    922.92 $\pm$ 237.08  5712.26 $\pm$ 2107.29
# 17     nash     HMF    931.58 $\pm$ 237.14  5710.22 $\pm$ 2106.88
# 18     nash     HPF   2215.5 $\pm$ 1535.04  4801.19 $\pm$ 1797.04
# 19     nash     LIF    931.17 $\pm$ 252.83  5710.49 $\pm$ 2103.51
#
#                        #V                          VT              RDI  \
# 0     736.58 $\pm$ 466.51         244.92 $\pm$ 244.94  0.74 $\pm$ 0.04
# 1     737.67 $\pm$ 466.34         520.58 $\pm$ 445.87  0.79 $\pm$ 0.05
# 2   8665.33 $\pm$ 6928.85   933013.83 $\pm$ 915263.49  0.89 $\pm$ 0.07
# 3     750.67 $\pm$ 474.54               0.0 $\pm$ 0.0  0.83 $\pm$ 0.09
